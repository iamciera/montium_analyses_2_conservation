# %%
#!/usr/bin/env python
#raw_to_alignment_key.py
#Ciera Martinez

import re
import pandas as pd
import numpy as np
import os, sys
from Bio import motifs
from Bio import SeqIO 
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio.Alphabet import IUPAC, generic_dna, generic_protein
from collections import defaultdict

# %%
#####################
## sys Inputs - to do
#####################

## read in alignment and motif 
## alignment = list(SeqIO.parse(sys.argv[1], "fasta"))

## Used later when marking output file
## alignment_file_name =  os.path.basename(sys.argv[1])
## print alignment_file_name

## Manual For testing
alignment = list(SeqIO.parse("../data/fasta/output_ludwig_eve-striped-2.fa", "fasta"))

raw_sequences = []
for record in alignment:
    raw_sequences.append(SeqRecord(record.seq.ungap("-"), id = record.id))

## make raw sequences all IUPAC.IUPACUnambiguousDNA()
raw_sequences_2 = []
for seq in raw_sequences:
    raw_sequences_2.append(Seq(str(seq.seq), IUPAC.IUPACUnambiguousDNA()))

###################################
## Searching for motif in all raw_sequences
#################################

raw_id = []
for seq in raw_sequences:
    raw_id.append(seq.id)
    
record_length = []
for record in raw_sequences_2:
    record_length.append(len(record))
# Out:
# ['ludwig_eve-striped-2||MEMB002F|+', 'ludwig_eve-striped-2||MEMB002A|+', 'ludwig_eve-striped-2||MEMB003C|-', 'ludwig_eve-striped-2||MEMB002C|+', 'ludwig_eve-striped-2||MEMB003B|+', 'ludwig_eve-striped-2||MEMB003F|+', 'ludwig_eve-striped-2||MEMB003D|-', 'ludwig_eve-striped-2||MEMB002D|+', 'ludwig_eve-striped-2||MEMB002E|-']
# [905, 868, 875, 862, 909, 868, 898, 913, 928]

# %%
##################
## get alignment position 
#################

remap_list = []
nuc_list = ['A', 'a', 'G', 'g', 'C', 'c', 'T', 't', 'N', 'n']

for i in range(0,9):
    counter = 0
    for xInd, x in enumerate(alignment[i].seq):    
        if x in nuc_list:
            remaps = {'raw_position': counter, 'align_position':xInd, 'species':alignment[i].id}
            counter += 1
            remap_list.append(remaps)
            
remap_DF = pd.DataFrame(remap_list)


## Attach File Name
remap_DF['alignment_file'] = "alignment_file_name"

## Write out Files
TFBS_map_DF_all.to_csv('../data/outputs/raw_to_alignment_key_output' + alignment_file_name + ".csv", sep='\t', na_rep="NA")
# Out:
#       align_position  raw_position                           species  \
# 0                  0             0  ludwig_eve-striped-2||MEMB002F|+
# 1                  1             1  ludwig_eve-striped-2||MEMB002F|+
# 2                  2             2  ludwig_eve-striped-2||MEMB002F|+
# 3                  3             3  ludwig_eve-striped-2||MEMB002F|+
# 4                  4             4  ludwig_eve-striped-2||MEMB002F|+
# 5                  5             5  ludwig_eve-striped-2||MEMB002F|+
# 6                  6             6  ludwig_eve-striped-2||MEMB002F|+
# 7                  7             7  ludwig_eve-striped-2||MEMB002F|+
# 8                  8             8  ludwig_eve-striped-2||MEMB002F|+
# 9                  9             9  ludwig_eve-striped-2||MEMB002F|+
# 10                10            10  ludwig_eve-striped-2||MEMB002F|+
# 11                11            11  ludwig_eve-striped-2||MEMB002F|+
# 12                12            12  ludwig_eve-striped-2||MEMB002F|+
# 13                13            13  ludwig_eve-striped-2||MEMB002F|+
# 14                14            14  ludwig_eve-striped-2||MEMB002F|+
# 15                15            15  ludwig_eve-striped-2||MEMB002F|+
# 16                16            16  ludwig_eve-striped-2||MEMB002F|+
# 17                17            17  ludwig_eve-striped-2||MEMB002F|+
# 18                18            18  ludwig_eve-striped-2||MEMB002F|+
# 19                19            19  ludwig_eve-striped-2||MEMB002F|+
# 20                20            20  ludwig_eve-striped-2||MEMB002F|+
# 21                21            21  ludwig_eve-striped-2||MEMB002F|+
# 22                22            22  ludwig_eve-striped-2||MEMB002F|+
# 23                23            23  ludwig_eve-striped-2||MEMB002F|+
# 24                24            24  ludwig_eve-striped-2||MEMB002F|+
# 25                25            25  ludwig_eve-striped-2||MEMB002F|+
# 26                26            26  ludwig_eve-striped-2||MEMB002F|+
# 27                27            27  ludwig_eve-striped-2||MEMB002F|+
# 28                28            28  ludwig_eve-striped-2||MEMB002F|+
# 29                29            29  ludwig_eve-striped-2||MEMB002F|+
# ...              ...           ...                               ...
# 7996            1080           898  ludwig_eve-striped-2||MEMB002E|-
# 7997            1081           899  ludwig_eve-striped-2||MEMB002E|-
# 7998            1082           900  ludwig_eve-striped-2||MEMB002E|-
# 7999            1083           901  ludwig_eve-striped-2||MEMB002E|-
# 8000            1084           902  ludwig_eve-striped-2||MEMB002E|-
# 8001            1085           903  ludwig_eve-striped-2||MEMB002E|-
# 8002            1112           904  ludwig_eve-striped-2||MEMB002E|-
# 8003            1113           905  ludwig_eve-striped-2||MEMB002E|-
# 8004            1114           906  ludwig_eve-striped-2||MEMB002E|-
# 8005            1115           907  ludwig_eve-striped-2||MEMB002E|-
# 8006            1116           908  ludwig_eve-striped-2||MEMB002E|-
# 8007            1117           909  ludwig_eve-striped-2||MEMB002E|-
# 8008            1118           910  ludwig_eve-striped-2||MEMB002E|-
# 8009            1119           911  ludwig_eve-striped-2||MEMB002E|-
# 8010            1120           912  ludwig_eve-striped-2||MEMB002E|-
# 8011            1121           913  ludwig_eve-striped-2||MEMB002E|-
# 8012            1122           914  ludwig_eve-striped-2||MEMB002E|-
# 8013            1123           915  ludwig_eve-striped-2||MEMB002E|-
# 8014            1124           916  ludwig_eve-striped-2||MEMB002E|-
# 8015            1125           917  ludwig_eve-striped-2||MEMB002E|-
# 8016            1126           918  ludwig_eve-striped-2||MEMB002E|-
# 8017            1127           919  ludwig_eve-striped-2||MEMB002E|-
# 8018            1128           920  ludwig_eve-striped-2||MEMB002E|-
# 8019            1129           921  ludwig_eve-striped-2||MEMB002E|-
# 8020            1130           922  ludwig_eve-striped-2||MEMB002E|-
# 8021            1131           923  ludwig_eve-striped-2||MEMB002E|-
# 8022            1132           924  ludwig_eve-striped-2||MEMB002E|-
# 8023            1133           925  ludwig_eve-striped-2||MEMB002E|-
# 8024            1134           926  ludwig_eve-striped-2||MEMB002E|-
# 8025            1135           927  ludwig_eve-striped-2||MEMB002E|-
#
#      alignment_file
# 0              test
# 1              test
# 2              test
# 3              test
# 4              test
# 5              test
# 6              test
# 7              test
# 8              test
# 9              test
# 10             test
# 11             test
# 12             test
# 13             test
# 14             test
# 15             test
# 16             test
# 17             test
# 18             test
# 19             test
# 20             test
# 21             test
# 22             test
# 23             test
# 24             test
# 25             test
# 26             test
# 27             test
# 28             test
# 29             test
# ...             ...
# 7996           test
# 7997           test
# 7998           test
# 7999           test
# 8000           test
# 8001           test
# 8002           test
# 8003           test
# 8004           test
# 8005           test
# 8006           test
# 8007           test
# 8008           test
# 8009           test
# 8010           test
# 8011           test
# 8012           test
# 8013           test
# 8014           test
# 8015           test
# 8016           test
# 8017           test
# 8018           test
# 8019           test
# 8020           test
# 8021           test
# 8022           test
# 8023           test
# 8024           test
# 8025           test
#
# [8026 rows x 4 columns]
